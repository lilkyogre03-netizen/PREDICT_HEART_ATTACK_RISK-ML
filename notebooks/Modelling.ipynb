# %%
# !pip install pandas
# !pip install pandas scikit-learn
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data=pd.read_csv("D:\DATA_Science\HEART ATTACK ML\data\processed\heart_clean.csv")

x= data.drop(columns="heart_attack_risk")
y=data["heart_attack_risk"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

modeltree=DecisionTreeClassifier()
modeltree.fit(x_train, y_train)
prediktree=modeltree.predict(x_test)
score1=accuracy_score(y_test, prediktree)
print(f"tree model : {score1}")

modelregres=LogisticRegression(max_iter=10000)
modelregres.fit(x_train, y_train)
predikreg=modelregres.predict(x_test)
score2=accuracy_score(y_test, predikreg)
print(f"regres model :{score2}")

modelfores=RandomForestClassifier()
modelfores.fit(x_train, y_train)
predikfores=modelfores.predict(x_test)
score3=accuracy_score(y_test, predikfores)
print(f"model fores :{score3}")

modelbayes=GaussianNB()
modelbayes.fit(x_train, y_train)
predikbayes=modelbayes.predict(x_test)
score4=accuracy_score(y_test, predikbayes)
print(f"model naivebayes :{score4}")

print(classification_report(y_test, modelregres.predict(x_test)))
print(classification_report(y_test, modeltree.predict(x_test)))
print(classification_report(y_test, modelbayes.predict(x_test)))
print(classification_report(y_test, modelfores.predict(x_test)))
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\lilky\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# tree model : 0.6605080831408776
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\lilky\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# regres model :0.789838337182448
# model fores :0.7705927636643572
# model naivebayes :0.775211701308699
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       755
#            1       0.77      0.72      0.74       544
#
#     accuracy                           0.79      1299
#    macro avg       0.79      0.78      0.78      1299
# weighted avg       0.79      0.79      0.79      1299
#
#               precision    recall  f1-score   support
#
# ...
